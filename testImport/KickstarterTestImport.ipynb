# %%
# Import libraries
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
import json

'''
# Look at this code to see what columns we can choose
with open('Kickstarter_2018-12-13T03_20_05_701Z.json') as f:
    foo = json.loads(f.readline())
    
foo['data']
'''

with open('Kickstarter_2018-12-13T03_20_05_701Z.json') as f:
    
    data = []
    
    # Iterate through each line in file which is a JSON object
    for line in f:
        
        # Load object
        obj = json.loads(line)
 
        # Choose columns
        item = []
        item.append(obj['data']['id'])
        item.append(obj['data']['name'])
        item.append(obj['data']['blurb'])
        item.append(obj['data']['goal'])
        item.append(obj['data']['pledged'])
        item.append(obj['data']['state'])
        item.append(obj['data']['country'])
        item.append(obj['data']['deadline'])
        item.append(obj['data']['created_at'])
        item.append(obj['data']['launched_at'])
        item.append(obj['data']['backers_count'])
        item.append(obj['data']['usd_pledged'])
        item.append(obj['data']['category']['name'])
        data.append(item)

# %%
# Fix columns list if adding/removing columns
columns = ['id', 'name', 'blurb', 'goal', 'pledged', 'state', 'country', 'deadline', 'created_at', 'launched_at', 'backers_count', 'usd_pledged', 'category']
df = pd.DataFrame(data, columns=columns)
df
# Out:
#                 id                                               name  \
# 0       1555581815                            Big Top Without Borders
# 1        583419300        The Story of "Pweep": From Egg - To Peacock
# 2       1745190062                                           DC Radio
# 3       1995203117            Ali Bangerz- two New Full Lenght Albums
# 4        359013399               Deja-Vu: Dissecting Memory on Camera
# 5       1102245275                      El Imaginario de Paula Sartre
# 6       1419014581                              Urban Rappel Getaway.
# 7        636175622                                             IndyGo
# 8       1439654389    White Rabbit Theatre's Thoroughly Modern Millie
# 9       1901995478                         Little Black Dress Opening
# 10      1838971687  DOITonLAN.NYC, Bringing LAN back to NYC (Cance...
# 11       968230682  Once Upon A Time In Shaolin - For Wu Fans, For...
# 12      1424131028  "Turtle Tales" a children's book for adults an...
# 13      1512733207                Breaking - A Film by Nicco Quiñones
# 14       534110976  The Decoder Ring Organization - A Mail-Order M...
# 15       430632124                                         Gypsy Gift
# 16      1568916628  LA BANDA QUE MEZCLA TODO / THE BAND THAT MIXES...
# 17      1523971283                    The Pedro Giraudo Tango Project
# 18      1910931382                               A History of the Sky
# 19      1606183549                            It Started with a Horse
# 20      1155033192                                            Vaulted
# 21      1092255926  NO WAY OUT BUT ONE:   a story of love and justice
# 22      1435640109  COLOR ME OBSESSED, the potentially true story ...
# 23       253544339                               Genesis Live Project
# 24       292065021                              Adventures in Parking
# 25      1200127418     Escape Masters: Wonderland & Residente Godinez
# 26      1932484736                          MC Lars - "Lars Attacks!"
# 27       764790674                            Kate Quigley Photoshoot
# 28      1471329171                                            Ravaged
# 29      1624029480                                         GO ON TOUR
# ...            ...                                                ...
# 207197  1027948584                     Artist Expansion Takes Chicago
# 207198   490050096  ash white: ethical fashion supporting makers +...
# 207199   982082961  The Half-Boy: Songs about Yearning for Home NE...
# 207200   937131806        A Nutty Solution - Peanut Butter for Rwanda
# 207201  1994895692     Bring a world-class art experience to Edmonton
# 207202   315915780                            Save Rainbow Bath House
# 207203   939790991                                 K180 Entertainment
# 207204  1545165962                                  Quennect4 Gallery
# 207205  2081760329               ICSHGE18 – Sustainability Conference
# 207206  1705898366  RESERVE NEW PHOTOBOOKS - TOKYO IS YOURS, FROZE...
# 207207  1020220283                Sare's Naturals Handmade in Harlem.
# 207208  1597223480                                   Alex and Friends
# 207209  1442708678                  4 WayTraction and alynnenterprise
# 207210   825344300  "KABUKIMONO" The way to Edinburgh Festival Fri...
# 207211   459200419            iGloo Home Energy Control For Everyone!
# 207212  2080717814  AL13 Premium UltraThin Aerospace Aluminium Bum...
# 207213  1277591915                  Protect H&R Train Garden Railroad
# 207214  1059082184  We Love Ribbon (a digital craft book)fashion/i...
# 207215   760734354  Sgnl - Make Phone Calls with Your Fingertip, l...
# 207216  1323627904                 New Release- Time Is Everything EP
# 207217  1491804824                                           A Future
# 207218   747785472                 Wobble Bowls by Speechless Studios
# 207219  1475620812  Help the Green Boys release their second album...
# 207220  1670340795                          Surprise Baby (Suspended)
# 207221  1614956035                                      into the wood
# 207222  1416671978    Stravinsky's Rite of Spring for Viola and Piano
# 207223  1436939986  Onda MX App: Mexico City art guide & living ar...
# 207224  1359359163      Ember – The Night Photography Tool for iPhone
# 207225  1455694749                        The Conor Clemmons Debut EP
# 207226  1243868537                          Personalized Vinyl Decals
#
#                                                     blurb       goal  \
# 0       A documentary about two circuses in remote cor...    25000.0
# 1       A multi-media IPad book telling the true story...      500.0
# 2       We are college students that get drunk and the...     3500.0
# 3       its Ali bangerz,its time to stand up for other...    20000.0
# 4       A young neuroscientist attempts to reconnect w...     5000.0
# 5          Una comedia sobre la existencia y la realidad.    20000.0
# 6       This is an ambitious film project for our Yout...      350.0
# 7       Creating an outlet for independent musicians t...    10000.0
# 8       White Rabbit Theatre brings highly entertainin...      700.0
# 9       Little Black Dress is a growing company. This ...    50000.0
# 10      Our dream and passion is to create a premier a...    20000.0
# 11      Wu Tang is releasing Once Upon A Time In Shaol...  5000000.0
# 12      Toby is Up-South Swamp’s beloved Snapping Turt...     6499.0
# 13      Breaking is a short matter of fact comedy- a t...     3000.0
# 14      Solve clues & unravel an interactive story wit...     8000.0
# 15      A young woman's search to find her strength an...     2200.0
# 16      We are Swing Original Monks, a band that mixes...    20000.0
# 17      Help us make Pedro Giraudo's first TANGO CD a ...    10000.0
# 18      A dynamic time-lapse visualization of the sky ...     3000.0
# 19      Mullinville KS, Population 289, Number of Stop...    10000.0
# 20      An Instillation fantasy world full of overlapp...     1600.0
# 21      NO WAY OUT BUT ONE is a documentary film about...    20000.0
# 22      The potentially true story of the most influen...      750.0
# 23      Help support Genesis and Cross Centered Music ...     1500.0
# 24      Bi-weekly podcast dedicated to the history, sc...      500.0
# 25      Escape Rooms inspired in Wonderland and Reside...    40000.0
# 26      Help MC Lars independently finish & release hi...     5000.0
# 27      Beautiful and artistic photos of comedian Kate...     3500.0
# 28      RAVAGED is a multiplayer vehicular FPS being d...    15000.0
# 29      HELP ME GO ON TOUR. BEEN CHASING THIS DREAM MY...     5000.0
# ...                                                   ...        ...
# 207197  As an eternal student of The Arts, I have been...      600.0
# 207198  ash white aims to support the people behind th...    20000.0
# 207199  In fourth grade I was in the play "The Half-bo...     6000.0
# 207200  I want to bring a nut grinding machine to Rwan...     3000.0
# 207201  Nuit Blanche Edmonton is a unique, free, conte...    10000.0
# 207202  Help Marina Fini save her living art installat...    30000.0
# 207203  A company that changes lives, dreams, and comm...    50000.0
# 207204  After nearly five years in Chicago's cultural ...     3600.0
# 207205  Advancement of sustainability based research w...    20000.0
# 207206  Reserve copies now of new limited edition phot...     6000.0
# 207207                                   Beards By Sarah.     5000.0
# 207208                            Laughs and more laughs!      300.0
# 207209  ALYNN Enterprise is the manufacturer of 4Way T...    70000.0
# 207210  We will take on the challenge of performing at...     8800.0
# 207211  Control your home appliances from the your sma...   250000.0
# 207212  Made from lightweight Aerospace Aluminum, Al13...    20000.0
# 207213  Help H&R Trains build a garden railroad. This ...    50000.0
# 207214  An inspiring, colourful project based ebook fe...     3500.0
# 207215  Sgnl is the smart strap that enables you to ma...    50000.0
# 207216  This is no ordinary EP . We need  your help ma...     3000.0
# 207217  An experimental short narrative about growing ...     5000.0
# 207218  Fund the US-based production of Speechless Stu...    10000.0
# 207219  The Green Boys are finished recording their se...     3000.0
# 207220  My fiancé and I are having our first baby toge...      500.0
# 207221  Our mission is to bring design objects created...    15000.0
# 207222  After 10 years of working and a successful pre...     6500.0
# 207223  La primera aplicación móvil, gratuita y biling...   250000.0
# 207224  iPhone light accessory for night photography. ...    30000.0
# 207225  This is a project that 100% reflects the phras...    10000.0
# 207226  Vinyl decorations taken to the next level.\n\n...     5000.0
#
#            pledged       state country    deadline  created_at  launched_at  \
# 0         27455.55  successful      US  1353256229  1339525842   1350660629
# 1           535.00  successful      US  1355949544  1351941026   1353357544
# 2             0.00      failed      CA  1418916011  1415917256   1416324011
# 3             0.00      failed      US  1449345000  1446664703   1446672167
# 4          6705.00  successful      US  1287200340  1284003536   1284042614
# 5             0.00      failed      MX  1519283268  1517506234   1517987268
# 6             1.00      failed      US  1494108214  1491416724   1491516214
# 7           100.00      failed      US  1507859506  1505265385   1505267506
# 8           700.00  successful      US  1510322746  1495133145   1506431146
# 9           170.00      failed      CA  1433094029  1427900848   1427910029
# 10         1350.00    canceled      US  1460908875  1455669701   1455728475
# 11        15406.92      failed      US  1402319859  1395937257   1397135859
# 12         7315.00  successful      US  1439136096  1392859953   1436803296
# 13         3281.00  successful      US  1322830800  1319178625   1319447203
# 14         8700.00  successful      US  1478147689  1472428399   1475555689
# 15         2345.00  successful      US  1321063200  1318023114   1318028830
# 16         7956.00      failed      US  1439949516  1433697859   1434765516
# 17        11255.00  successful      US  1505093881  1501866972   1502501881
# 18         3578.00  successful      US  1276905060  1269110042   1269209136
# 19        10001.00  successful      US  1278779640  1270575110   1271267294
# 20          516.00      failed      US  1377983160  1375160790   1376323289
# 21        20220.00  successful      US  1309884649  1303832240   1305996649
# 22          863.00  successful      US  1281369600  1277906696   1277911783
# 23            0.00      failed      US  1345600800  1343840851   1344347255
# 24         1512.00  successful      US  1426773898  1422890177   1423148698
# 25        68763.80  successful      MX  1532235540  1526828518   1530017578
# 26        23282.67  successful      US  1305177456  1300856859   1302585456
# 27         4791.00  successful      US  1533157449  1529553439   1530565449
# 28        38767.66  successful      US  1337529410  1330794420   1333641410
# 29            0.00      failed      US  1419196923  1415194008   1416604923
# ...            ...         ...     ...         ...         ...          ...
# 207197        5.00      failed      US  1329170400  1326141627   1326304256
# 207198     3156.00      failed      AU  1506088500  1491971313   1502792632
# 207199     6604.00  successful      US  1394077764  1348945906   1391485764
# 207200      311.00      failed      US  1455207884  1446215824   1452615884
# 207201    11501.29  successful      CA  1538027760  1536075334   1536779837
# 207202     2370.00        live      US  1546402320  1540409649   1541965645
# 207203        0.00      failed      US  1429308000  1411242166   1424824617
# 207204     3650.00  successful      US  1273726740  1265062241   1266015263
# 207205        5.00      failed      IT  1503909755  1498458433   1498725755
# 207206     6880.00  successful      AU  1498385040  1487723994   1496584542
# 207207       48.00      failed      US  1407848565  1405253026   1405256565
# 207208       70.00      failed      US  1455823592  1454096200   1454527592
# 207209       50.00      failed      US  1484359305  1472058434   1481767305
# 207210        0.00    canceled      GB  1432393980  1429787887   1429801980
# 207211      473.00      failed      AU  1406929593  1401959282   1404337593
# 207212    86250.54  successful      US  1360789260  1354646534   1356614170
# 207213        1.00      failed      US  1447735142  1440210195   1442547542
# 207214     1237.00      failed      GB  1430416800  1425323337   1426938043
# 207215  1469202.00  successful      US  1475935244  1471938345   1472652044
# 207216      120.00      failed      US  1522572790  1519964293   1519984390
# 207217     5252.00  successful      US  1392323101  1389239224   1389731101
# 207218    42384.23  successful      US  1337785268  1331495503   1335193268
# 207219     4213.00  successful      US  1368244740  1365637089   1366404388
# 207220        0.00   suspended      US  1426477132  1422416534   1422592732
# 207221        2.00        live      IT  1545390867  1542304807   1542798867
# 207222     6511.00  successful      US  1338582258  1335216463   1335990258
# 207223   285797.80        live      MX  1544679169  1541625703   1542087169
# 207224    22407.00      failed      US  1395502892  1382718586   1392914492
# 207225    10001.00  successful      US  1416507024  1412186535   1413738624
# 207226      135.00      failed      US  1386533026  1383779758   1383941026
#
#         backers_count      usd_pledged           category
# 0                 170         27455.55        Documentary
# 1                  10            535.0   Children's Books
# 2                   0              0.0              Audio
# 3                   0              0.0        World Music
# 4                  62           6705.0        Documentary
# 5                   0              0.0             Comedy
# 6                   1              1.0             Action
# 7                   1            100.0        World Music
# 8                   5            700.0            Musical
# 9                   2      134.0628449            Couture
# 10                 30           1350.0    Gaming Hardware
# 11                688         15406.92            Hip-Hop
# 12                 74           7315.0   Children's Books
# 13                 38           3281.0             Shorts
# 14                 94           8700.0         Live Games
# 15                 43           2345.0             Shorts
# 16                167           7956.0        World Music
# 17                155          11255.0        World Music
# 18                 52           3578.0        Documentary
# 19                 55          10001.0        Documentary
# 20                 19            516.0     Conceptual Art
# 21                110          20220.0        Documentary
# 22                 18            863.0        Documentary
# 23                  0              0.0            Hip-Hop
# 24                 13           1512.0              Audio
# 25                119   3424.078292964         Live Games
# 26                520         23282.67            Hip-Hop
# 27                 54           4791.0             People
# 28               1221         38767.66        Video Games
# 29                  0              0.0            Hip-Hop
# ...               ...              ...                ...
# 207197              1              5.0         Public Art
# 207198             35    2495.75145012      Ready-to-wear
# 207199            107           6604.0     Country & Folk
# 207200              9            311.0        Small Batch
# 207201             15  8746.7336902967         Public Art
# 207202             48           2370.0      Installations
# 207203              0              0.0    Performance Art
# 207204             48           3650.0    Performance Art
# 207205              1         5.674216           Academic
# 207206            124     5119.4095136         Photobooks
# 207207              4             48.0                DIY
# 207208              2             70.0   Radio & Podcasts
# 207209              1             50.0  Fabrication Tools
# 207210              0              0.0    Performance Art
# 207211              4     445.66386843           Hardware
# 207212           1426         86250.54     Product Design
# 207213              1              1.0                DIY
# 207214             39    1826.93315495                DIY
# 207215           8117        1469202.0          Wearables
# 207216              1            120.0               Kids
# 207217             91           5252.0       Experimental
# 207218            581         42384.23             Design
# 207219            105           4213.0     Country & Folk
# 207220              0              0.0              Video
# 207221              2        2.2892384       Architecture
# 207222             25           6511.0    Performance Art
# 207223            181   14175.95670703                Art
# 207224            287          22407.0           Hardware
# 207225             94          10001.0     Country & Folk
# 207226              4            135.0     Graphic Design
#
# [207227 rows x 13 columns]
